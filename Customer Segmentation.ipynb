# %% [markdown]
# IMPORTING ALL REQUIRED LIBRARIES FOR DATA CLEANING AND EXPLORATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Customer Purchase Behavior Datasets.xlsx")
df.head()
# Out:
#                             Customer_ID   Age  Gender    Income Location  \
# 0  9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1  ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2  9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3  4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4  18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
#
#   Customer_Segment                        Transaction_ID                Date  \
# 0             High  d66461e5-ec3e-45c2-9975-2730e05b2613 2023-11-29 10:04:00
# 1           Medium  c5c0316b-d2e3-432c-8b1c-52c87a1d2832 2023-10-10 22:46:00
# 2              Low  38c8ca15-c1f3-44c1-9cd3-05a3982480fa 2024-06-04 11:21:00
# 3             High  38d1ff0c-1248-498b-bdf9-55fbbe999ed4 2024-08-16 06:17:00
# 4              Low  7f83bfe5-27e0-4d30-b426-dbe642d5c7a1 2024-01-03 18:36:00
#
# ...

# %%
df.info()                    #RETRIEVES THE INFORAMTION OF THE DATA INCLUDES NO.OF ROWS AND NO.OF COLUMNS AND NON-NULL ROWS AND ITS DATATYPE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            4997 non-null   float64
#  2   Gender                         4995 non-null   object
#  3   Income                         4996 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               4997 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %% [markdown]
# AS PER THE ABOVE FUNCTION THE COLUMNS AGE,GENDER,INCOME,LOCATION,CUSTOMER_SEGMENT HAVING NULL VALUES

# %% [markdown]
# We can find the count for the descrete features like Gender, Location, Customer_Segment,Product_Category

# %%
print("value counts for Gender")
df['Gender'].value_counts()
# Out:
# value counts for Gender
# Gender
# Male      2453
# Female    2360
# Other      182
# Name: count, dtype: int64

# %%
print("value counts for Location")
df['Location'].value_counts()
# Out:
# value counts for Location
# Location
# City      3007
# Suburb    1490
# Rural      499
# Name: count, dtype: int64

# %%
print("value counts for Customer_Segment")
df['Customer_Segment'].value_counts()
# Out:
# value counts for Customer_Segment
# Customer_Segment
# Low       2524
# Medium    1482
# High       991
# Name: count, dtype: int64

# %%
print("value counts for Product_Category")
df['Product_Category'].value_counts()
# Out:
# value counts for Product_Category
# Product_Category
# Toys           910
# Furniture      852
# Electronics    830
# Clothing       805
# Books          803
# Groceries      800
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age         Income                           Date     Quantity  \
# count  4997.000000    4996.000000                           5000  5000.000000
# mean     43.589954  108251.229384  2024-03-10 19:20:30.419999744     2.500600
# min      18.000000   20005.000000            2023-03-13 03:00:00     1.000000
# 25%      31.000000   62912.000000            2023-09-06 18:50:45     1.000000
# 50%      43.000000  107605.000000            2024-03-13 01:00:30     3.000000
# 75%      56.000000  153708.750000            2024-09-08 22:39:15     3.000000
# max      69.000000  199992.000000            2025-03-11 22:58:00     4.000000
# std      14.921685   52111.502273                            NaN     1.115638
#
#         Unit_Price  Total_Spent  Loyalty_Points_Used  Previous_Purchases  \
# count  5000.000000  5000.000000          5000.000000         5000.000000
# mean    253.622340   634.181692           246.914800           24.909200
# ...

# %% [markdown]
# CLEANING DATA
# FOR NUMERICAL COLUMNS FILLING WITH EITHER WITH MEAN,MEDIAN
# FOR DISCRETE COLUMNS FILLING WITH MODE

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df.info()      #here we can see that the column(feature) age hasbeen replaced by median of that feature
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            5000 non-null   float64
#  2   Gender                         4995 non-null   object
#  3   Income                         4996 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               4997 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)   #the feature gender has been replaced by its mode value

# %%
df.info()           #we can see that the gender feature has successfully replaced with its mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            5000 non-null   float64
#  2   Gender                         5000 non-null   object
#  3   Income                         4996 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               4997 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %%
df['Income'].fillna(df['Income'].mean(),inplace=True)   #the feature income is replaced by its mean value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            5000 non-null   float64
#  2   Gender                         5000 non-null   object
#  3   Income                         5000 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               4997 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %%
df['Customer_Segment'].fillna(df['Customer_Segment'].mode()[0],inplace=True)   #as customer segment feature is a discrete feature it has been replaced with mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            5000 non-null   float64
#  2   Gender                         5000 non-null   object
#  3   Income                         5000 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               5000 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %%
df["Location"] = df.groupby("Customer_Segment")["Location"].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else "Unknown"))
#it fills the missing data with mode by based on the customer segment feature 
#forex: if customer segment having premium then the corresponding location feature is replaced by mode of the premium value i.e New York

# %%
df.info()                  #now we can find that all the values are filled and replaced
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            5000 non-null   float64
#  2   Gender                         5000 non-null   object
#  3   Income                         5000 non-null   float64
#  4   Location                       5000 non-null   object
#  5   Customer_Segment               5000 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS: Here we can do univariate bivariate and multi variate Analysis

# %% [markdown]
# UNIVARIATE ANALYSIS FOR THE FEATURES: Age,Gender,Location,Product_Category,Customer_Segment

# %%
#UNIVARIATE ANALYSIS FOR THE FEATURE AGE

plt.hist(df["Age"], bins=5, color="blue", edgecolor="black", alpha=0.7)
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# From the above graph we can analyse that the age between 20-30 and 60-70 are purchasing mostly

# %%
#Gender

df["Gender"].value_counts().plot(kind="bar", color=["blue", "pink"], edgecolor="black", alpha=0.7)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#Location

df['Location'].value_counts().plot(kind="bar",color=['red','blue','purple'],edgecolor='black',alpha=0.7)
plt.title("Location distribution")
plt.xlabel("Location")
plt.ylabel("Count of Location")
plt.show()

# %% [markdown]
# From this we clearly finds that the customers are more from city than compared to suburd and rural areas

# %%
#Product_Category
df['Product_Category'].value_counts().plot(kind="bar",color=['red','magenta','purple','blue','green','violet'],edgecolor='black',alpha=0.8)
plt.title("Distribution of Product Category")
plt.xlabel("Product Category")
plt.ylabel("count of each product")
plt.show()

# %% [markdown]
# Bi-Variate Analysis

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
plt.scatter(df["Age"], df["Total_Spent"], alpha=0.5, color="blue", edgecolors="black")
plt.title("Age vs. Total Spending")
plt.xlabel("Age")
plt.ylabel("Total Spent")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["Gender"], y=df["Total_Spent"], palette="coolwarm")
plt.title("Total Spending by Gender")
plt.xlabel("Gender")
plt.ylabel("Total Spent")
plt.show()

# %% [markdown]
# FROM ABOVE PLOT BOTH THE MALE AND FEMALE SPENDS EQUALLY

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df["Preferred_Shopping_Time"], y=df["Total_Spent"], palette="viridis")
plt.title("Spending vs Preferred Shopping Time")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the above bar plot we can understand that customers doesnot prefer the specific time but from the barplot we can observe a slight
# difference that evening time has highest spending of time with a short difference

# %%
from sklearn.preprocessing import StandardScaler

# Select only numerical features
numeric_df = df.select_dtypes(include=['number'])

# Apply StandardScaler to normalize data
scaled_data = StandardScaler().fit_transform(numeric_df)

# Create a DataFrame after scaling
scaled_df = pd.DataFrame(scaled_data, columns=numeric_df.columns)

# Compute correlation matrix
correlation_matrix = scaled_df.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap (Scaled Data)")
plt.show()

# %% [markdown]
# From the above heatmap we can observe that "Unit_Price and Total Spent","Quantity and Total_spent" are highly related to each other.

# %%
plt.figure(figsize=(12,5))
df.boxplot(column="Total_Spent", by="Customer_Segment", grid=False, patch_artist=True, boxprops=dict(facecolor="lightgreen"))
plt.title("Total Spending by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Spent")
plt.suptitle("")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the boxplot a slight difference can be found for the feature customer_segment "LOW"

# %%
plt.figure(figsize=(12,5))
df.groupby("Product_Category")["Total_Spent"].mean().nlargest(10).plot(kind="bar", color="orange", edgecolor="black", alpha=0.7)
plt.title("Top 10 Product Categories by Average Spending")
plt.xlabel("Product Category")
plt.ylabel("Average Total Spent")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Here there is not much difference in the avg of total_spent and their product_category

# %%
plt.figure(figsize=(12,5))
df.groupby("Location")["Total_Spent"].mean().nlargest(10).plot(kind="bar", color="red", edgecolor="black", alpha=0.7)
plt.title("Top 10 Locations by Average Spending")
plt.xlabel("Location")
plt.ylabel("Average Total Spent")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Here we can find that the "RURAL" areas are spending more than compared to "CITY" and "SUBURB"

# %% [raw]
# Feature Engineering (Create RFM Features)
# Feature Engineering helps in improving model performance by creating new meaningful features.
#
#
# Recency, Frequency, and Monetary (RFM) Analysis
#
#
# Recency (R): How recently a customer made a purchase (days since last purchase)
#
# Frequency (F): Total number of purchases made by a customer
#
# Monetary (M): 	Total amount spent by a customer

# %%
from datetime import datetime

# Converting 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Calculating Recency (Days since last purchase)
latest_date = df['Date'].max()
df['Recency'] = (latest_date - df['Date']).dt.days

# Calculating Frequency (Total Transactions per Customer)
frequency_df = df.groupby('Customer_ID')['Transaction_ID'].count().reset_index()
frequency_df.columns = ['Customer_ID', 'Frequency']

# Calculating Monetary Value (Total Amount Spent per Customer)
monetary_df = df.groupby('Customer_ID')['Total_Spent'].sum().reset_index()
monetary_df.columns = ['Customer_ID', 'Monetary']

# Merging RFM features into one dataset
rfm_df = df[['Customer_ID', 'Recency']].drop_duplicates().merge(frequency_df, on='Customer_ID').merge(monetary_df, on='Customer_ID')


# Fill any NaN values after conversion (if needed)
df.fillna(0, inplace=True)

# Display the RFM DataFrame
print(rfm_df.head())
# Out:
#                             Customer_ID  Recency  Frequency  Monetary
# 0  9a66bec2-57cf-4fb1-9fe6-79bae4fb4612      468          1    254.88
# 1  ef0d40d1-8e2d-4c64-b807-c982ce8865ac      518          1    106.17
# 2  9de2b87c-6554-4050-9456-9f56a923149d      280          1    409.48
# 3  4095a429-b32a-4eba-ba3d-3fa22591c0a0      207          1    335.49
# 4  18a218aa-3d30-4cf1-bc4a-890dcbb446d9      433          1    547.10

# %%
print(df.columns)
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income', 'Location',
#        'Customer_Segment', 'Transaction_ID', 'Date', 'Product_Category',
#        'Product_ID', 'Quantity', 'Unit_Price', 'Total_Spent', 'Payment_Method',
#        'Discount_Applied', 'Loyalty_Points_Used', 'Previous_Purchases',
#        'Average_Spending', 'Last_Purchase_Days_Ago',
#        'Browsing_Time_Before_Purchase', 'Preferred_Shopping_Time',
#        'Customer_Satisfaction_Rating', 'Recency'],
#       dtype='object')

# %% [raw]
# AS HERE WE ARE NOT GETTING FREQUENCY AND MONETARY FEATURES THAT ARE CREAYED IN FEATURE ENGINEERING PROCESS
# HENCE WE CREATED A COLUMNS SEPARATELY AND WE MERGE THESE COLUMNS INTO A SINGLE DATASET

# %%
df_frequency = df.groupby("Customer_ID")["Transaction_ID"].count().reset_index()
df_frequency.columns = ["Customer_ID", "Frequency"]

# %%
print(df_frequency.columns)
# Out:
# Index(['Customer_ID', 'Frequency'], dtype='object')

# %%
df_monetary = df.groupby("Customer_ID")["Total_Spent"].sum().reset_index()
df_monetary.columns = ["Customer_ID", "Monetary"]

# %%
df_monetary.columns
# Out:
# Index(['Customer_ID', 'Monetary'], dtype='object')

# %%
rfm_df = df[["Customer_ID", "Recency"]].drop_duplicates()
rfm_df = rfm_df.merge(df_frequency, on="Customer_ID", how="left")
rfm_df = rfm_df.merge(df_monetary, on="Customer_ID", how="left")

# Fill missing values (if any)
rfm_df.fillna(0, inplace=True)

# Display final RFM dataset
print(rfm_df.head())
# Out:
#                             Customer_ID  Recency  Frequency  Monetary
# 0  9a66bec2-57cf-4fb1-9fe6-79bae4fb4612      468          1    254.88
# 1  ef0d40d1-8e2d-4c64-b807-c982ce8865ac      518          1    106.17
# 2  9de2b87c-6554-4050-9456-9f56a923149d      280          1    409.48
# 3  4095a429-b32a-4eba-ba3d-3fa22591c0a0      207          1    335.49
# 4  18a218aa-3d30-4cf1-bc4a-890dcbb446d9      433          1    547.10

# %% [raw]
# Now Iam using the models(algorithns) to segment customers based on their purchasing behaviour
# For this iam using the clustering model K-means algorithm

# %% [raw]
# Now that we have Recency, Frequency, and Monetary (RFM) features, let's segment customers using K-Means Clustering.

# %%
from sklearn.cluster import KMeans

# Select only RFM features
rfm_features = rfm_df[['Recency', 'Frequency', 'Monetary']]

# Standardize the data
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_features)

# Convert back to DataFrame
rfm_scaled_df = pd.DataFrame(rfm_scaled, columns=['Recency', 'Frequency', 'Monetary'])

# %% [raw]
# We need to find the best number of clusters (k).

# %%
# Finding the optimal number of clusters using Elbow Method
wcss = []  # Within-cluster sum of squares
for k in range(1, 11):  # Testing k from 1 to 10
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(rfm_scaled_df)
    wcss.append(kmeans.inertia_)

# Plot Elbow Curve
plt.figure(figsize=(8,5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal k')
plt.show()

# %% [raw]
# Apply K-Means Clustering
# The k value is difficult in finding because the graph is decreasing when k is increasing. so we use Silhouette Score to find K.

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for k in range(2, 11):  # Start from 2 clusters
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(rfm_scaled_df)
    score = silhouette_score(rfm_scaled_df, labels)
    silhouette_scores.append(score)

# Plot Silhouette Scores
plt.figure(figsize=(8,5))
plt.plot(range(2, 11), silhouette_scores, marker='o', linestyle='--')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal K')
plt.show()

# %% [raw]
# From this graph we can find K because when the value=3 the Silhouette Score is high hence we take the k value as 3

# %% [raw]
# Standardizing RFM Values

# %%
# Select only RFM features
rfm_features = rfm_df[['Recency', 'Frequency', 'Monetary']]

# Standardize the data
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_features)

# Convert back to DataFrame
rfm_scaled_df = pd.DataFrame(rfm_scaled, columns=['Recency', 'Frequency', 'Monetary'])

# %% [raw]
# Applying k means algorithm

# %%
# Apply K-Means with K=3
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
rfm_df['Cluster'] = kmeans.fit_predict(rfm_scaled_df)

# %% [raw]
# Analysing Cluster Analysis

# %%
# Count of customers in each cluster
print(rfm_df['Cluster'].value_counts())

# Cluster-wise mean values of RFM features
cluster_analysis = rfm_df.groupby('Cluster')[['Recency', 'Frequency', 'Monetary']].mean()
print(cluster_analysis)
# Out:
# Cluster
# 1    1949
# 2    1881
# 0    1170
# Name: count, dtype: int64
#             Recency  Frequency     Monetary
# Cluster
# 0        350.813675        1.0  1348.693906
# 1        557.109287        1.0   418.903905
# 2        176.514088        1.0   412.808549

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Cluster', y='Monetary', data=rfm_df)
plt.title('Customer Segmentation Based on Monetary Value')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=rfm_df['Recency'], y=rfm_df['Monetary'], hue=rfm_df['Cluster'], palette='viridis')
plt.title('Customer Segmentation (Recency vs. Monetary)')
plt.show()

# %% [raw]
# Understanding Cluster Characteristics

# %% [raw]
# checking the average RFM values for each cluster

# %%
cluster_analysis = rfm_df.groupby('Cluster')[['Recency', 'Frequency', 'Monetary']].mean()
print(cluster_analysis)
# Out:
#             Recency  Frequency     Monetary
# Cluster
# 0        350.813675        1.0  1348.693906
# 1        557.109287        1.0   418.903905
# 2        176.514088        1.0   412.808549

# %% [markdown]
# Understanding Customer Segments (K=3)
# Cluster	            Recency (R)	               Frequency (F)	Monetary (M)	           Customer Type
#
# 0	              350 days (Moderate)	              1	        High (₹1348.69)	        High-Value Customers
#
# 1	              557 days (Very High)	              1	        Low (₹418.90)	        Lost Customers
#
# 2	              176 days (Low)	                  1	        Low (₹412.80)	       Recent Low Spenders

# %% [markdown]
# Cluster Interpretation & Business Strategies
#
#
# Cluster 1 : High-Value Customers (Best Customers)
#
# Recency: They purchased 350 days ago, which is moderate.
#
# Monetary: They spend the most (₹1348.69 on average).
#
#
#
# Cluster 2: Lost Customers (Churned)
#
# Recency: 557 days ago (They haven't purchased for a long time).
#
# Monetary: ₹418.90 (Low spending).
#
#
#
# Cluster 3: Recent Low Spenders
#
# Recency: 176 days ago (They purchased recently).
#
# Monetary: ₹412.80 (Low spending).

# %% [markdown]
# As we got the frequency 1 so, to improve segmentation we can use the k-means with K value 2 and we cluster based on the monetary and recency features

# %%
# Select only Recency and Monetary
rfm_features = rfm_df[['Recency', 'Monetary']]

# Standardize the data
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_features)

# Convert back to DataFrame
rfm_scaled_df = pd.DataFrame(rfm_scaled, columns=['Recency', 'Monetary'])

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
rfm_df['Cluster'] = kmeans.fit_predict(rfm_scaled_df)

# %%
# Count of customers in each cluster
print(rfm_df['Cluster'].value_counts())

# Cluster-wise mean values of Recency & Monetary
cluster_analysis = rfm_df.groupby('Cluster')[['Recency', 'Monetary']].mean()
print(cluster_analysis)
# Out:
# Cluster
# 0    2509
# 1    2491
# Name: count, dtype: int64
#             Recency    Monetary
# Cluster
# 0        547.362296  595.815528
# 1        182.637094  672.825090

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=rfm_df['Recency'], y=rfm_df['Monetary'], hue=rfm_df['Cluster'])
plt.title('Customer Segmentation (Recency vs. Monetary)')
plt.xlabel('Recency (Days Since Last Purchase)')
plt.ylabel('Monetary (Total Spending)')
plt.show()

# %% [markdown]
# From the above plot we can observe from both of the clusters 0 and 1 most of the purchases is done between the range of 500-1000
